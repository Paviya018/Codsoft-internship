# %%
import re

# %%
def simple_chatbot (user_input):

  rules = {
    r'hello|hi|hey': 'Hello there! How can I assist you today?',
    r'how are you': 'I’m just a bot, but thanks for asking! How can I help you?',
    r'your name|who are you': 'I am a friendly chatbot here to chat with you.',
    r'what\'s up|what is up': 'Not much! What’s on your mind?',
    r'bye|goodbye': 'Goodbye! Take care and have a wonderful day.',
    r'see you|see ya': 'See you later! If you have more questions, feel free to ask.',
    r'tell me about the meaning of life': 'The meaning of life is a profound and subjective question. It often depends on one’s personal beliefs and experiences.',
    r'life advice': 'Embrace each day, learn from experiences, and cherish meaningful connections with others.',
    r'tell me about love': 'Love is a complex and powerful emotion that can manifest in various forms, such as romantic, familial, and platonic love.',
    r'tips for a healthy relationship': 'Communication, trust, and mutual respect are key ingredients for a healthy and fulfilling relationship.',
    r'tell me a science fact': 'The Earth is approximately 4.54 billion years old, and life likely originated around 3.5 billion years ago.',
    r'interesting facts about space': 'Space is vast and mysterious, with billions of galaxies containing trillions of stars. There’s so much to explore!',
    r'tell me about artificial intelligence': 'Artificial intelligence involves creating machines that can perform tasks that typically require human intelligence.',
    r'latest tech trends': 'Current tech trends include advancements in AI, machine learning, blockchain, and the Internet of Things (IoT).',
    r'tell me a joke': 'Why don’t scientists trust atoms? Because they make up everything!',
    r'favorite movie': 'I don’t watch movies, but I hear "The Matrix" is quite popular among machines.',
    r'tell me about dogs': 'Dogs are known for their loyalty and come in various breeds, each with its unique characteristics.',
    r'facts about cats': 'Cats are independent animals and make great companions. Did you know they can sleep up to 16 hours a day?',
    r'tell me about ancient history': 'Ancient history spans civilizations like Mesopotamia, Egypt, Greece, and Rome, each with rich cultures and achievements.',
    r'history of technology': 'The history of technology is fascinating, from the invention of the wheel to the rise of the internet and beyond.',
    r'tell me about trees': 'Trees play a vital role in the environment by providing oxygen, absorbing carbon dioxide, and offering habitats for diverse species.',
    r'interesting facts about birds': 'Birds are fascinating creatures with diverse species. Did you know that some birds can mimic human speech?',
    r'tell me about chocolate': 'Chocolate is made from cacao beans and is enjoyed worldwide. It has a rich history and comes in various delicious forms.',
    r'favorite recipes': 'I don’t cook, but I hear chocolate chip cookies are a favorite among humans!',
    r'best travel destinations': 'There are countless beautiful travel destinations worldwide, from tropical beaches to historic cities. It depends on your interests!',
    r'tips for traveling solo': 'Traveling solo can be a rewarding experience. Plan ahead, stay aware of your surroundings, and embrace new adventures.',
    r'recommend a book': 'For a classic, you might enjoy "To Kill a Mockingbird" by Harper Lee. If you prefer fantasy, try "The Hobbit" by J.R.R. Tolkien.',
    r'favorite genre': 'I don’t have personal preferences, but many enjoy science fiction and fantasy for their imaginative worlds.',
    r'favorite music genre': 'I don’t have personal preferences, but many enjoy a wide range of genres, from pop and rock to classical and jazz.',
       r'song recommendations': 'For a classic, try "Bohemian Rhapsody" by Queen. For something more recent, "Blinding Lights" by The Weeknd is popular.',
    r'tips for a healthy lifestyle': 'Maintain a balanced diet, stay physically active, get enough sleep, and manage stress for a healthier life.',
    r'importance of hydration': 'Hydration is crucial for overall health. Drinking enough water helps regulate body temperature and supports bodily functions.',
    r'tell me about time travel': 'Time travel is a popular concept in science fiction, often explored in movies and books. It involves moving between different points in time.',
    r'favorite sci-fi movie': 'If I had preferences, I might enjoy "Blade Runner" for its exploration of artificial intelligence.',
    r'tell me about ancient civilizations': 'Ancient civilizations like the Egyptians, Greeks, and Romans contributed significantly to human history, art, and culture.',
    r'famous historical figures': 'Historical figures like Leonardo da Vinci, Marie Curie, and Nelson Mandela made lasting impacts on the world.',
  }

  for pattern, response in rules.items():
    if re.search (pattern, user_input, re.IGNORECASE):
      return response

  return "I'm sorry, I did not understand that. Can you please rephrase?"

while True:
  user_input = input("You: ")
  if user_input.lower() == 'exit':
    print("Chatbot: Goodbye!")
    break

  bot_response = simple_chatbot(user_input)
  print("Chatbot: ", bot_response)
# Out:
# You: hi
# Chatbot:  Hello there! How can I assist you today?
